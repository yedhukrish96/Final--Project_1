# %%
import pandas as pd

# %%
data = pd.read_csv("final_df_forml.csv")
display(data.shape)
data.head()
# Out:
# (671205, 14)
#    Unnamed: 0          sector   country currency  term_in_months  \
# 0           0            Food  Pakistan      PKR              12
# 1           1  Transportation  Pakistan      PKR              11
# 2           2  Transportation     India      INR              43
# 3           3            Arts  Pakistan      PKR              11
# 4           4            Food  Pakistan      PKR              14
#
#    lender_count repayment_interval  posted_year posted_month  disbursed_year  \
# 0            12          irregular         2014      January            2013
# 1            14          irregular         2014      January            2013
# 2             6             bullet         2014      January            2013
# 3             8          irregular         2014      January            2013
# 4            16            monthly         2014      January            2013
#
#   disbursed_month  num_male_borrowers  num_female_borrowers  \
# ...

# %%
data1 = data.head(50000)

# %%
data1
# Out:
#        Unnamed: 0          sector   country currency  term_in_months  \
# 0               0            Food  Pakistan      PKR              12
# 1               1  Transportation  Pakistan      PKR              11
# 2               2  Transportation     India      INR              43
# 3               3            Arts  Pakistan      PKR              11
# 4               4            Food  Pakistan      PKR              14
# ...           ...             ...       ...      ...             ...
# 49995       49995     Agriculture   Armenia      USD              26
# 49996       49996     Agriculture  Honduras      HNL              22
# 49997       49997    Personal Use    Uganda      UGX               7
# 49998       49998         Housing   Vietnam      VND              20
# 49999       49999     Agriculture  Honduras      HNL              14
#
#        lender_count repayment_interval  posted_year posted_month  \
# 0                12          irregular         2014      January
# ...

# %%
data1.to_csv("data_for_ml.csv", index=False)
